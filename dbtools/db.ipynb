# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path
ROOT_PATH = Path().resolve().parent
if str(ROOT_PATH) not in sys.path:
    sys.path.insert(ROOT_PATH, 1)

# %%
import ipywidgets as widgets
from IPython.display import display
from autoeq.constants import PEQ_CONFIGS
from autoeq.batch_processing import batch_processing
ROOT_PATH = Path().resolve().parent
from dbtools.rtings_crawler import RtingsCrawler
from dbtools.crinacle_crawler import CrinacleCrawler
from dbtools.oratory1990_crawler import Oratory1990Crawler
from dbtools.innerfidelity_crawler import InnerfidelityCrawler
from dbtools.headphonecom_crawler import HeadphonecomCrawler
from dbtools.squig_crawler import SquigCrawler, SquigCrawlerManager
from dbtools.prune_results import prune_results
from dbtools.update_result_indexes import update_all_indexes
from dbtools.create_webapp_data import write_entries_and_measurements, write_targets
from dbtools.constants import TARGETS_PATH, MEASUREMENTS_PATH, RESULTS_PATH

# %% [markdown]
# ## Crawling and Parsing
# Additional Python packages are required for processing the measurements:
# ```bash
# python -m pip install -U -r dbtools/requirements.txt
# ```
#
# This notebook uses IPyWidgets
# ```bash
# jupyter nbextension enable --py widgetsnbextension --sys-prefix
# ```
#
# Finally install IPython kernel
# ```bash
# python -m ipykernel install --user --name="autoeq"
# ```
#
# Measurement crawlers require [Google Chrome](https://www.google.com/chrome/) installed and
# [ChromeDriver](https://googlechromelabs.github.io/chrome-for-testing/) binary in the measurements folder (or anywhere
# in the PATH).
#
# Measurement crawlers also require C++. This should be installed by default on Linux but on Windows you need to install
# Microsoft Visual Studio build tools for this. https://visualstudio.microsoft.com/downloads/ ->
# "Tools for Visual Studio 2019" -> "Build Tools for Visual Studio 2019".
#
# oratory1990 crawler requires Ghostscript installed: https://www.ghostscript.com/download/gsdnld.html

# %% [markdown]
# ### Crinacle
# Download measurement data from Drive folder to `measurements/crinacle/raw_data/` before running this!
#
# * `IEM Measurements/IEC60318-4 IEM Measurements (TSV txt)` into `AutoEq/measurements/crinacle/raw_data/IEC60318-4 IEM Measurements (TSV txt)`
# * `IEM Measurements/4620 IEM Measurements` into `AutoEq/measurements/crinacle/raw_data/4620 IEM Measurements`
# * `HP Measurements/EARS + 711 (TSV txt) (Legacy)` into `AutoEq/measurements/crinacle/raw_data/EARS + 711 (TSV txt) (Legacy)`
# * `GRAS 43AG-7` into `AutoEq/measurements/crinacle/raw_data/GRAS 43AG-7`

# %%
crawler = CrinacleCrawler()
crawler.run()
display(crawler.widget)

# %%
crawler.prune_measurements(dry_run=True)
# Out:
# No measurements need to be pruned

# %%
crawler.process(new_only=True)

# %% [markdown]
# ### oratory1990
# oratory1990 crawler fetches all measurements from https://www.reddit.com/r/oratory1990/wiki/index/list_of_presets/, downloads PDFs and reads the frequency response measurement data from the PDFs. Parsing the PDFs requires [Ghostscript](https://www.ghostscript.com/download/gsdnld.html) to be installed on the system.

# %%
crawler = Oratory1990Crawler()

# %%
crawler.run()
display(crawler.widget)

# %%
crawler.prune_measurements(dry_run=False)
# Out:
# Removed "C:\Users\jaakko\code\AutoEq\measurements\oratory1990\data\over-ear\AKG K712 (Dekoni sheepskin Earpads).csv"

# %%
crawler.process(new_only=True)
# Out:
#   0%|          | 0/612 [00:00<?, ?it/s]

# %% [markdown]
# ### Rtings
# Rtings crawler fetches all measurements from https://www.rtings.com/headphones/1-[2,4,5]/graph and downloads raw FR JSON files and parses them.

# %%
crawler = RtingsCrawler()

# %%
crawler.run()
display(crawler.widget)

# %%
crawler.prune_measurements(dry_run=True)
# Out:
# No measurements need to be pruned

# %%
crawler.process(new_only=True)
# Out:
#   0%|          | 0/723 [00:00<?, ?it/s]

# %% [markdown]
# ### Squig.link
# Several databases included in squig.link
#
# **TODO:** rig information for cralwers, somehow

# %%
manager = SquigCrawlerManager()
print(', '.join(sorted([crawler.username for crawler in manager.crawlers])))
# Out:
# achoreviews, adri-n, aftersound, animagus, ankramutt, arn, auricularesargentina, aydn, bakkwatan, bedrock, bryaudioreviews, bukanaudiophile, cammyfi, cqtek, dchpgall, dhrme, dl, eliseaudio, eplv, fahryst, filk, freeryder05, gadgetrytech, harpo, hbb, hobbytalk, hore, ianfann, iemworld, ish, jacstone, jaytiss, kazi, kr0mka, kuulokenurkka, listener, melatonin, mmagtech, musicafe, nymz, practiphile, precog, pw, ragnarok, recode, regancipher, rg, sai, seanwee, smirk, soundcheck39, superreview, suporsalad, tanchjim, tedthepraimortis, tgx78, therollo9, timmyv, tonedeafmonk, vortexreviews, vsg, yanyin

# %%
display(manager.run('auricularesargentina').widget)

# %%
display(manager.run('bakkwatan').widget)

# %%
display(manager.run('cqtek').widget)

# %%
display(manager.run('dhrme').widget)

# %%
display(manager.run('fahryst').widget)

# %%
display(manager.run('filk').widget)

# %%
display(manager.run('freeryder05').widget)

# %%
# Not in squigsites.json
#display(manager.run('gadgetgenerations').widget)

# %%
display(manager.run('harpo').widget)

# %%
# Rig not known yet
#display(manager.run('ish').widget)

# %%
# Rig not known yet
#display(manager.run('jacstone').widget)

# %%
display(manager.run('jaytiss').widget)

# %%
display(manager.run('kazi').widget)

# %%
display(manager.run('kr0mka').widget)

# %%
display(manager.run('kuulokenurkka').widget)

# %%
# Not in squigsites.json
#display(manager.run('mini').widget)

# %%
# Not in squigsites.json
#display(manager.run('psykano').widget)

# %%
display(manager.run('regancipher').widget)

# %%
display(manager.run('rg').widget)

# %%
# Not in squigsites.json
#display(manager.run('sdlib').widget)

# %%
# Almost all measurements are with 3rd party eartips
#display(manager.run('smirk').widget)

# %%
# Rig not known yet
#display(manager.run('soundcheck39').widget)

# %%
display(manager.run('superreview').widget)

# %%
display(manager.run('tedthepraimortis').widget)

# %%
# Not in squigsites.json
#display(manager.run('therollo9').widget)

# %%
display(manager.run('tonedeafmonk').widget)

# %%
# Not in squigsites.json
#display(manager.run('wdym').widget)

# %%
# Only 3 models
#display(manager.run('yanyin').widget)

# %%
# Not in squigsites.json
#display(manager.run('zamo').widget)

# %%
manager.process('auricularesargentina')
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]

# %% [markdown]
# ## Rename Measurements
# Sometimes measurements are named incorrectly or previously only one sample existed and now multiple samples have been measured and so the original one needs to be renamed as "<name> (sample 1)"

# %%
crinacle = CrinacleCrawler()
headphonecom = HeadphonecomCrawler()
innerfidelity = InnerfidelityCrawler()
oratory1990 = Oratory1990Crawler()
rtings = RtingsCrawler(driver=oratory1990.driver)

renames = [
    {'old_name': 'SeeAudio x Crincale Yume Midnight', 'new_name': 'SeeAudio x Crinacle Yume Midnight', 'crawlers': [crinacle]},
]
for rename in renames:
    for crawler in rename['crawlers']:
        crawler.rename_measurement(old_name=rename['old_name'], new_name=rename['new_name'], dry_run=False)

# %% [markdown]
# ## Prune Results
# Check if obsolete results (e.g. because of renaming) exist and remove them

# %%
prune_results(databases=['crinacle', 'oratory1990', 'Headphone.com Legacy', 'Innerfidelity', 'Rtings'], dry_run=True)

# %% [markdown]
# ## Update Results
# Creates new results from the measurements. `eq_kwargs` are parameters shared by all jobs.

# %%
eq_kwargs = {
    'parametric_eq': True, 'ten_band_eq': True, 'convolution_eq': True,
    'parametric_eq_config': [PEQ_CONFIGS['4_PEAKING_WITH_LOW_SHELF'], PEQ_CONFIGS['4_PEAKING_WITH_HIGH_SHELF']],
    'fs': [44100, 48000],
    'thread_count': 0,
}

# %% [markdown]
# #### oratory1990 Over-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('oratory1990', 'data', 'over-ear'),
    output_dir=RESULTS_PATH.joinpath('oratory1990', 'over-ear'),
    target=TARGETS_PATH.joinpath('Harman over-ear 2018 without bass.csv'),
    bass_boost_gain=6.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=True, **eq_kwargs)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### oratory1990 In-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('oratory1990', 'data', 'in-ear'),
    output_dir=RESULTS_PATH.joinpath('oratory1990', 'in-ear'),
    target=TARGETS_PATH.joinpath('AutoEq in-ear.csv'),
    bass_boost_gain=9.5, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/188 [00:00<?, ?it/s]

# %% [markdown]
# #### oratory1990 Earbud

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('oratory1990', 'data', 'earbud'),
    output_dir=RESULTS_PATH.joinpath('oratory1990', 'earbud'),
    target=TARGETS_PATH.joinpath('AutoEq in-ear.csv'),
    bass_boost_gain=0.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### crinacle GRAS 43AG-7 On-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('crinacle', 'data', 'over-ear', 'GRAS 43AG-7'),
    output_dir=RESULTS_PATH.joinpath('crinacle', 'GRAS 43AG-7 over-ear'),
    target=TARGETS_PATH.joinpath('Harman over-ear 2018 without bass.csv'),
    bass_boost_gain=6.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/331 [00:00<?, ?it/s]

# %% [markdown]
# #### crinacle EARS+711 Over-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('crinacle', 'data', 'over-ear', 'EARS + 711'),
    output_dir=RESULTS_PATH.joinpath('crinacle', 'EARS + 711 over-ear'),
    target=TARGETS_PATH.joinpath('crinacle EARS + 711 Harman over-ear 2018 without bass.csv'),
    bass_boost_gain=6.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/65 [00:00<?, ?it/s]

# %% [markdown]
# #### crinacle 4620 In-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('crinacle', 'data', 'in-ear', 'Bruel & Kjaer 4620'),
    output_dir=RESULTS_PATH.joinpath('crinacle', 'Bruel & Kjaer 4620 in-ear'),
    target=TARGETS_PATH.joinpath('Diffuse field 5128 -1dB per octave.csv'),
    bass_boost_gain=0.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/169 [00:00<?, ?it/s]

# %% [markdown]
# #### crinacle 711 In-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('crinacle', 'data', 'in-ear', '711'),
    output_dir=RESULTS_PATH.joinpath('crinacle', '711 in-ear'),
    target=TARGETS_PATH.joinpath('AutoEq in-ear.csv'),
    bass_boost_gain=9.5, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=True, **eq_kwargs)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### Rtings Over-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Rtings', 'data', 'over-ear'),
    output_dir=RESULTS_PATH.joinpath('Rtings', 'over-ear'),
    target=TARGETS_PATH.joinpath('Rtings Harman over-ear 2018 without bass.csv'),
    bass_boost_gain=6.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=True, **eq_kwargs)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# #### Rtings In-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Rtings', 'data', 'in-ear'),
    output_dir=RESULTS_PATH.joinpath('Rtings', 'in-ear'),
    target=TARGETS_PATH.joinpath('Rtings AutoEq in-ear.csv'),
    bass_boost_gain=9.5, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=True, **eq_kwargs)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# #### Rtings Earbud

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Rtings', 'data', 'earbud'),
    output_dir=RESULTS_PATH.joinpath('Rtings', 'earbud'),
    target=TARGETS_PATH.joinpath('Rtings Autoeq in-ear.csv'),
    bass_boost_gain=0.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]

# %% [markdown]
# #### Innerfidelity In-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Innerfidelity', 'data', 'over-ear'),
    output_dir=RESULTS_PATH.joinpath('Innerfidelity', 'over-ear'),
    target=TARGETS_PATH.joinpath('Innerfidelity Harman over-ear 2018 without bass.csv'),
    bass_boost_gain=6.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/612 [00:00<?, ?it/s]

# %% [markdown]
# #### Innerfidelity In-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Innerfidelity', 'data', 'in-ear'),
    output_dir=RESULTS_PATH.joinpath('Innerfidelity', 'in-ear'),
    target=TARGETS_PATH.joinpath('Innerfidelity AutoEq in-ear.csv'),
    bass_boost_gain=6.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/307 [00:00<?, ?it/s]

# %% [markdown]
# #### Innerfidelity Earbud

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Innerfidelity', 'data', 'earbud'),
    output_dir=RESULTS_PATH.joinpath('Innerfidelity', 'earbud'),
    target=TARGETS_PATH.joinpath('Innerfidelity AutoEq in-ear.csv'),
    bass_boost_gain=0.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# #### Headphone.com Legacy Over-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Headphone.com Legacy', 'data', 'over-ear'),
    output_dir=RESULTS_PATH.joinpath('Headphone.com Legacy', 'over-ear'),
    target=TARGETS_PATH.joinpath('Headphone.com Legacy Harman over-ear 2018 without bass.csv'),
    bass_boost_gain=6.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/225 [00:00<?, ?it/s]

# %% [markdown]
# #### Headphone.com Legacy In-ear

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Headphone.com Legacy', 'data', 'in-ear'),
    output_dir=RESULTS_PATH.joinpath('Headphone.com Legacy', 'in-ear'),
    target=TARGETS_PATH.joinpath('Headphone.com Legacy AutoEq in-ear.csv'),
    bass_boost_gain=9.5, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]

# %% [markdown]
# #### Headphone.com Legacy Earbud

# %%
_ = batch_processing(
    input_dir=MEASUREMENTS_PATH.joinpath('Headphone.com Legacy', 'data', 'earbud'),
    output_dir=RESULTS_PATH.joinpath('Headphone.com Legacy', 'earbud'),
    target=TARGETS_PATH.joinpath('Headphone.com Legacy AutoEq in-ear.csv'),
    bass_boost_gain=0.0, bass_boost_fc=105, bass_boost_q=0.7,
    new_only=False, **eq_kwargs)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ## Update Indexes
# Updates recommended results, full results, DB specific results, HeSuVi results and ranking table.

# %%
update_all_indexes()
# Out:
# Creating ranking index...
#   0%|          | 0/3664 [00:00<?, ?it/s]
# Creating recommendations index...
# Creating full index...
# Creating source indices...
# Creating HeSuVi ZIP archive...
#   0%|          | 0/3664 [00:00<?, ?it/s]

# %% [markdown]
# #### Data for webapp

# %%
write_entries_and_measurements()
# Out:
#   0%|          | 0/4599 [00:00<?, ?it/s]

# %%
write_targets()

# %% [markdown]
# ## Deploy
# 1. Add files to Git, commit and push
# 2. Upload webapp data to server

# %% [markdown]
# # Sandbox
# Don't run these! Random exploration while developing.

# %%
from pathlib import Path
from tqdm.auto import tqdm
import re
import requests
from selenium.webdriver.common.by import By
import json
from bs4 import BeautifulSoup
import numpy as np
import json
from autoeq.frequency_response import FrequencyResponse

# %%
crawler = CrinacleCrawler()
crawler.crawl()

for item in crawler.crawl_index:
    index_item = crawler.name_index.find_one(url=item.url)
    book = crawler.book_maps[item.url.split('/')[-2]]
    normalized_file_name = crawler.normalize_file_name(item.url.split('/')[-1])
    source_name = book[normalized_file_name] if normalized_file_name in book else None
    if index_item is not None and source_name is not None and index_item.source_name != source_name:
        print(f'{index_item.source_name} --> {source_name}')
        index_item.source_name = source_name
crawler.write_name_index()
# Out:
# Annotation --> BLON Annotation
# Annotation --> BLON Annotation
# Aria --> Moondrop Aria
# Aria --> Moondrop Aria
# None --> BLON BL-03
# None --> BLON BL-03
# Blessing 3 --> Moondrop Blessing 3
# Blessing 3 --> Moondrop Blessing 3
# Cencibel --> Tripowin Cencibel
# Cencibel --> Tripowin Cencibel
# None --> oBravo Cupid
# None --> oBravo Cupid
# Dawn --> Fearless Dawn
# Dawn --> Fearless Dawn
# 7Hz-Salnotes Dioko Prototype --> 7Hz-Salnotes Dioko
# 7Hz-Salnotes Dioko Prototype --> 7Hz-Salnotes Dioko
# Dusk --> Moondrop Blessing2:Dusk
# Dusk --> Moondrop Blessing2:Dusk
# ERX --> Etymotic ERX
# ERX --> Etymotic ERX
# F1 --> KBEar F1
# F1 --> KBEar F1
# FHE Eclipse --> FiiO FHE:Eclipse
# FHE Eclipse --> FiiO FHE:Eclipse
# Galileo --> LetShuoer Galileo
# Galileo --> LetShuoer Galileo
# GR-I --> Guide Ray GR-I
# GR-I --> Guide Ray GR-I
# H27 --> Shuoer H27
# H27 --> Shuoer H27
# H3 --> Kinera H3
# H3 --> Kinera H3
# i4 TRI --> TRI i4
# i4 TRI --> TRI i4
# IE200 --> Sennheiser IE200
# IE200 --> Sennheiser IE200
# IER-Z1R --> Sony IER-Z1R
# IER-Z1R --> Sony IER-Z1R
# Kylin --> Whizzer Kylin
# Kylin --> Whizzer Kylin
# Lan --> Moondrop Lan
# Lan --> Moondrop Lan
# ThieAudio Legacy 2 (L2) --> Thieaudio Legacy 2 (L2)
# ThieAudio Legacy 2 (L2) --> Thieaudio Legacy 2 (L2)
# Legacy 3 00 --> Thieaudio Legacy 3 (L3) (Universal) (00 setting)
# Legacy 3 00 --> Thieaudio Legacy 3 (L3) (Universal) (00 setting)
# Legacy 3 02 --> Thieaudio Legacy 3 (L3) (Universal) (02 setting)
# Legacy 3 02 --> Thieaudio Legacy 3 (L3) (Universal) (02 setting)
# Legacy 3 10 --> Thieaudio Legacy 3 (L3) (Universal) (10 setting)
# Legacy 3 10 --> Thieaudio Legacy 3 (L3) (Universal) (10 setting)
# Legacy 3 12 --> Thieaudio Legacy 3 (L3) (Universal) (12 setting)
# Legacy 3 12 --> Thieaudio Legacy 3 (L3) (Universal) (12 setting)
# Legacy 5 --> Thieaudio Legacy 5 (L5)
# Legacy 5 --> Thieaudio Legacy 5 (L5)
# Sony MH755 S1 --> Sony MH755
# Sony MH755 S1 --> Sony MH755
# Midnight --> See Audio Yume:Midnight
# Midnight --> See Audio Yume:Midnight
# ThieAudio Monarch Mk2 --> Thieaudio Monarch Mk2
# ThieAudio Monarch Mk2 --> Thieaudio Monarch Mk2
# Moray --> Razer Moray
# Moray --> Razer Moray
# Neo BG --> Shozy Neo BG
# Neo BG --> Shozy Neo BG
# New HANA --> Tanchjim New HANA (2021)
# New HANA --> Tanchjim New HANA (2021)
# Nio M20 --> 64 Audio Nio (m20)
# Nio M20 --> 64 Audio Nio (m20)
# P3 --> Jomo Audio P3
# P3 --> Jomo Audio P3
# Prestige --> Thieaudio Prestige
# Prestige --> Thieaudio Prestige
# Qinglong --> KBEar Qinglong
# Qinglong --> KBEar Qinglong
# Quarks --> Moondrop Quarks
# Quarks --> Moondrop Quarks
# Rhombus --> Tripowin Rhombus
# Rhombus --> Tripowin Rhombus
# RX100 --> Ovidius RX100 Qin Armour
# RX100 --> Ovidius RX100 Qin Armour
# S12 Pro --> LetShuoer S12 Pro
# S12 Pro --> LetShuoer S12 Pro
# Stellaris --> Moondrop Stellaris
# Stellaris --> Moondrop Stellaris
# Alclair Studio4 --> Softears Studio 4
# Alclair Studio4 --> Softears Studio 4
# T2 DLC --> Tin HiFi T2 DLC
# T2 DLC --> Tin HiFi T2 DLC
# Tanya --> Tanchjim Tanya
# Tanya --> Tanchjim Tanya
# Timeless AE --> 7Hz-Salnotes Timeless AE
# Timeless AE --> 7Hz-Salnotes Timeless AE
# UFO-111 --> UFOEar UFO-111
# UFO-111 --> UFOEar UFO-111
# None --> UFOEar UFO-112
# None --> UFOEar UFO-112
# ThieAudio V16 Divinity --> Thieaudio V16 Divinity
# ThieAudio V16 Divinity --> Thieaudio V16 Divinity
# VSonic VS7 --> Vsonic VS7
# VSonic VS7 --> Vsonic VS7
# Warrior --> TFZ Warrior
# Warrior --> TFZ Warrior
# YISS --> Urbanfun YBF-ISS014
# YISS --> Urbanfun YBF-ISS014
# None --> 7Hz-Salnotes Zero
# None --> 7Hz-Salnotes Zero
# Zero Tanchjim --> Tanchjim Zero
# Zero Tanchjim --> Tanchjim Zero
# None --> Truthear Zero
# None --> Truthear Zero
# None --> Truthear Zero:RED S1 (Bass+)
# None --> Truthear Zero:RED S1 (Bass+)
# None --> Truthear Zero:RED S1
# None --> Truthear Zero:RED S1
# None --> Truthear Zero:RED S10 (Bass+)
# None --> Truthear Zero:RED S10 (Bass+)
# None --> Truthear Zero:RED S10
# None --> Truthear Zero:RED S10
# None --> Truthear Zero:RED S2 (Bass+)
# None --> Truthear Zero:RED S2 (Bass+)
# None --> Truthear Zero:RED S2
# None --> Truthear Zero:RED S2
# None --> Truthear Zero:RED S3 (Bass+)
# None --> Truthear Zero:RED S3 (Bass+)
# None --> Truthear Zero:RED S3
# None --> Truthear Zero:RED S3
# None --> Truthear Zero:RED S4 (Bass+)
# None --> Truthear Zero:RED S4 (Bass+)
# None --> Truthear Zero:RED S4
# None --> Truthear Zero:RED S4
# None --> Truthear Zero:RED S5 (Bass+)
# None --> Truthear Zero:RED S5 (Bass+)
# None --> Truthear Zero:RED S5
# None --> Truthear Zero:RED S5
# None --> Truthear Zero:RED S6 (Bass+)
# None --> Truthear Zero:RED S6 (Bass+)
# None --> Truthear Zero:RED S6
# None --> Truthear Zero:RED S6
# None --> Truthear Zero:RED S7 (Bass+)
# None --> Truthear Zero:RED S7 (Bass+)
# None --> Truthear Zero:RED S7
# None --> Truthear Zero:RED S7
# None --> Truthear Zero:RED S8 (Bass+)
# None --> Truthear Zero:RED S8 (Bass+)
# None --> Truthear Zero:RED S8
# None --> Truthear Zero:RED S8
# None --> Truthear Zero:RED S9 (Bass+)
# None --> Truthear Zero:RED S9 (Bass+)
# None --> Truthear Zero:RED S9
# None --> Truthear Zero:RED S9
# AB-1266 Phi CC Lite --> Abyss AB-1266 Phi CC Lite
# AB-1266 Phi CC Lite --> Abyss AB-1266 Phi CC Lite
# AB-1266 Phi CC Lite --> Abyss AB-1266 Phi CC Lite
# AB-1266 Phi CC Lite --> Abyss AB-1266 Phi CC Lite
# AB-1266 Phi CC Lite --> Abyss AB-1266 Phi CC Lite
# Aeolus --> ZMF Headphones Aeolus
# Aeolus --> ZMF Headphones Aeolus
# Aeolus --> ZMF Headphones Aeolus
# Aeolus --> ZMF Headphones Aeolus
# Aeolus --> ZMF Headphones Aeolus
# Aeolus UP --> ZMF Headphones Aeolus w/ Universal Perforated pads
# Aeolus UP --> ZMF Headphones Aeolus w/ Universal Perforated pads
# Aeolus UP --> ZMF Headphones Aeolus w/ Universal Perforated pads
# Aeolus UP --> ZMF Headphones Aeolus w/ Universal Perforated pads
# Aeolus UP --> ZMF Headphones Aeolus w/ Universal Perforated pads
# Atticus --> ZMF Headphones Atticus
# Atticus --> ZMF Headphones Atticus
# Atticus --> ZMF Headphones Atticus
# Atticus --> ZMF Headphones Atticus
# Atticus --> ZMF Headphones Atticus
# Auteur Blackwood --> ZMF Headphones Auteur Blackwood
# Auteur Blackwood --> ZMF Headphones Auteur Blackwood
# Auteur Blackwood UP --> ZMF Headphones Auteur Blackwood w/ Universal Perforated pads
# Auteur Blackwood UP --> ZMF Headphones Auteur Blackwood w/ Universal Perforated pads
# Auteur Blackwood UP --> ZMF Headphones Auteur Blackwood w/ Universal Perforated pads
# Auteur Blackwood UP --> ZMF Headphones Auteur Blackwood w/ Universal Perforated pads
# Auteur Blackwood UP --> ZMF Headphones Auteur Blackwood w/ Universal Perforated pads
# Auteur Cocobolo --> ZMF Headphones Auteur Cocobolo
# Auteur Cocobolo --> ZMF Headphones Auteur Cocobolo
# Auteur Cocobolo --> ZMF Headphones Auteur Cocobolo
# Auteur Cocobolo --> ZMF Headphones Auteur Cocobolo
# Auteur Cocobolo --> ZMF Headphones Auteur Cocobolo
# Auteur Teak --> ZMF Headphones Auteur Teak
# Auteur Teak --> ZMF Headphones Auteur Teak
# Auteur Teak --> ZMF Headphones Auteur Teak
# Auteur Teak --> ZMF Headphones Auteur Teak
# Auteur Teak --> ZMF Headphones Auteur Teak
# CD900ST --> Sony MDR-CD900ST
# CD900ST --> Sony MDR-CD900ST
# CD900ST --> Sony MDR-CD900ST
# CD900ST --> Sony MDR-CD900ST
# CD900ST --> Sony MDR-CD900ST
# Eikon --> ZMF Headphones Eikon
# Eikon --> ZMF Headphones Eikon
# Eikon --> ZMF Headphones Eikon
# Eikon --> ZMF Headphones Eikon
# Eikon --> ZMF Headphones Eikon
# Elegia --> Focal Elegia
# Elegia --> Focal Elegia
# Elegia --> Focal Elegia
# Elegia --> Focal Elegia
# Elegia --> Focal Elegia
# None --> Sennheiser Electronic HD800 S1
# None --> Sennheiser Electronic HD800 S1
# None --> Sennheiser Electronic HD800 S1
# None --> Sennheiser Electronic HD800 S1
# None --> Sennheiser Electronic HD800 S1
# None --> Sennheiser Electronic HD800 S2 (SDR modified)
# None --> Sennheiser Electronic HD800 S2 (SDR modified)
# None --> Sennheiser Electronic HD800 S2 (SDR modified)
# None --> Sennheiser Electronic HD800 S2 (SDR modified)
# None --> Sennheiser Electronic HD800 S2 (SDR modified)
# HE1000 V1 --> Hifiman Electronics HE1000 V1
# HE1000 V1 --> Hifiman Electronics HE1000 V1
# HE1000 V1 --> Hifiman Electronics HE1000 V1
# HE1000 V1 --> Hifiman Electronics HE1000 V1
# HE1000 V1 --> Hifiman Electronics HE1000 V1
# HE5SE --> Hifiman Electronics HE5SE
# HE5SE --> Hifiman Electronics HE5SE
# HE5SE --> Hifiman Electronics HE5SE
# HE5SE --> Hifiman Electronics HE5SE
# HE5SE --> Hifiman Electronics HE5SE
# LCD-2 Dekoni Fen --> Audeze LCD-2 Dekoni Fen
# LCD-2 Dekoni Fen --> Audeze LCD-2 Dekoni Fen
# LCD-2 Dekoni Fen --> Audeze LCD-2 Dekoni Fen
# LCD-2 Dekoni Fen --> Audeze LCD-2 Dekoni Fen
# LCD-2 Dekoni Fen --> Audeze LCD-2 Dekoni Fen
# LCD-2C Closed --> Audeze LCD-2C Closed
# LCD-2C Closed --> Audeze LCD-2C Closed
# LCD-2C Closed --> Audeze LCD-2C Closed
# LCD-2C Closed --> Audeze LCD-2C Closed
# LCD-2C Closed --> Audeze LCD-2C Closed
# LCD-2C --> Audeze LCD-2C
# LCD-2C --> Audeze LCD-2C
# LCD-2C --> Audeze LCD-2C
# LCD-2C --> Audeze LCD-2C
# LCD-2C --> Audeze LCD-2C
# LCD-X --> Audeze LCD-X
# LCD-X --> Audeze LCD-X
# LCD-X --> Audeze LCD-X
# LCD-X --> Audeze LCD-X
# LCD-X --> Audeze LCD-X
# M30 --> Audio Technica ATH-M30
# M30 --> Audio Technica ATH-M30
# M30 --> Audio Technica ATH-M30
# M30 --> Audio Technica ATH-M30
# M30 --> Audio Technica ATH-M30
# M40 --> Audio Technica ATH-M40
# M40 --> Audio Technica ATH-M40
# M40 --> Audio Technica ATH-M40
# M40 --> Audio Technica ATH-M40
# M40 --> Audio Technica ATH-M40
# M50X --> Audio Technica ATH-M50X
# M50X --> Audio Technica ATH-M50X
# M50X --> Audio Technica ATH-M50X
# M50X --> Audio Technica ATH-M50X
# M50X --> Audio Technica ATH-M50X
# MX-4 --> Audeze MX-4
# MX-4 --> Audeze MX-4
# MX-4 --> Audeze MX-4
# MX-4 --> Audeze MX-4
# MX-4 --> Audeze MX-4
# NDH20 --> Neumann NDH20
# NDH20 --> Neumann NDH20
# NDH20 --> Neumann NDH20
# NDH20 --> Neumann NDH20
# NDH20 --> Neumann NDH20
# Panda Passive --> Drop (Massdrop) Panda (Passive)
# Panda Passive --> Drop (Massdrop) Panda (Passive)
# Panda Passive --> Drop (Massdrop) Panda (Passive)
# Panda Passive --> Drop (Massdrop) Panda (Passive)
# Panda Passive --> Drop (Massdrop) Panda (Passive)
# Phi --> Abyss Diana Phi
# Phi --> Abyss Diana Phi
# Phi --> Abyss Diana Phi
# Phi --> Abyss Diana Phi
# Phi --> Abyss Diana Phi
# SR-007 --> Stax SR-007
# SR-007 --> Stax SR-007
# SR-007 --> Stax SR-007
# SR-007 --> Stax SR-007
# SR-007 --> Stax SR-007
# None --> ZMF Headphones Verite Closed
# None --> ZMF Headphones Verite Closed
# None --> ZMF Headphones Verite Closed
# None --> ZMF Headphones Verite Closed
# None --> ZMF Headphones Verite Closed
# Verum 1 --> Verum 1 (One)
# Verum 1 --> Verum 1 (One)
# Verum 1 --> Verum 1 (One)
# Verum 1 --> Verum 1 (One)
# Verum 1 --> Verum 1 (One)
# 700 --> Bose Noise Cancelling Headphones 700
# 700 --> Bose Noise Cancelling Headphones 700
# 700 --> Bose Noise Cancelling Headphones 700
# 700 --> Bose Noise Cancelling Headphones 700
# 700 --> Bose Noise Cancelling Headphones 700
# 700 --> Bose Noise Cancelling Headphones 700
# None --> Meze 99 Classic
# None --> Meze 99 Classic
# None --> Meze 99 Classic
# None --> Meze 99 Classic
# None --> Meze 99 Classic
# None --> Meze 99 Classic
# 99 Neo --> Meze 99 Neo
# 99 Neo --> Meze 99 Neo
# 99 Neo --> Meze 99 Neo
# 99 Neo --> Meze 99 Neo
# 99 Neo --> Meze 99 Neo
# 99 Neo --> Meze 99 Neo
# A1000Z --> Audio Technica ATH-A1000Z
# A1000Z --> Audio Technica ATH-A1000Z
# A1000Z --> Audio Technica ATH-A1000Z
# Aeolus (perf Universe suede) --> ZMF Aeolus (Perforated suede Universe pads)
# Aeolus (perf Universe suede) --> ZMF Aeolus (Perforated suede Universe pads)
# Aeon 2 Closed --> DCA (Dan Clark Audio) Aeon 2 Closed
# Aeon 2 Closed --> DCA (Dan Clark Audio) Aeon 2 Closed
# Aeon 2 Closed --> DCA (Dan Clark Audio) Aeon 2 Closed
# Aeon 2 Closed --> DCA (Dan Clark Audio) Aeon 2 Closed
# Aeon 2 Closed --> DCA (Dan Clark Audio) Aeon 2 Closed
# Aeon 2 Closed --> DCA (Dan Clark Audio) Aeon 2 Closed
# Aeon 2 Noire --> DCA (Dan Clark Audio) Aeon 2 Noire
# Aeon 2 Noire --> DCA (Dan Clark Audio) Aeon 2 Noire
# Aeon 2 Noire --> DCA (Dan Clark Audio) Aeon 2 Noire
# Aeon 2 Noire --> DCA (Dan Clark Audio) Aeon 2 Noire
# Aeon 2 Noire --> DCA (Dan Clark Audio) Aeon 2 Noire
# Aeon 2 Noire --> DCA (Dan Clark Audio) Aeon 2 Noire
# Aeon 2 Open --> DCA (Dan Clark Audio) Aeon 2 Open
# Aeon 2 Open --> DCA (Dan Clark Audio) Aeon 2 Open
# Aeon 2 Open --> DCA (Dan Clark Audio) Aeon 2 Open
# Aeon 2 Open --> DCA (Dan Clark Audio) Aeon 2 Open
# Aeon 2 Open --> DCA (Dan Clark Audio) Aeon 2 Open
# Aeon 2 Open --> DCA (Dan Clark Audio) Aeon 2 Open
# Aeon Flow Closed (Medium damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Medium damping)
# Aeon Flow Closed (Medium damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Medium damping)
# Aeon Flow Closed (Medium damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Medium damping)
# Aeon Flow Closed (Medium damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Medium damping)
# Aeon Flow Closed (Medium damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Medium damping)
# Aeon Flow Closed (Medium damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Medium damping)
# Aeon Flow Closed (Minimum damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Minimum damping)
# Aeon Flow Closed (Minimum damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Minimum damping)
# Aeon Flow Closed (Minimum damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Minimum damping)
# Aeon Flow Closed (Minimum damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Minimum damping)
# Aeon Flow Closed (Minimum damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Minimum damping)
# Aeon Flow Closed (Minimum damping) --> MrSpeakers (Dan Clark Audio) Aeon Flow Closed (Minimum damping)
# Aeon Flow Open --> MrSpeakers (Dan Clark Audio) Aeon Flow Open
# Aeon Flow Open --> MrSpeakers (Dan Clark Audio) Aeon Flow Open
# Aeon Flow Open --> MrSpeakers (Dan Clark Audio) Aeon Flow Open
# Aeon Flow Open --> MrSpeakers (Dan Clark Audio) Aeon Flow Open
# Aeon Flow Open --> MrSpeakers (Dan Clark Audio) Aeon Flow Open
# Aeon Flow Open --> MrSpeakers (Dan Clark Audio) Aeon Flow Open
# AH-D5000 --> Denon AH-D5000
# AH-D5000 --> Denon AH-D5000
# AH-D5000 --> Denon AH-D5000
# AH-D5000 --> Denon AH-D5000
# AH-D5000 --> Denon AH-D5000
# AH-D5000 --> Denon AH-D5000
# AH-D5200 --> Denon AH-D5200
# AH-D5200 --> Denon AH-D5200
# AH-D5200 --> Denon AH-D5200
# AH-D5200 --> Denon AH-D5200
# AH-D5200 --> Denon AH-D5200
# AH-D5200 --> Denon AH-D5200
# AH-D7200 --> Denon AH-D7200
# AH-D7200 --> Denon AH-D7200
# AH-D7200 --> Denon AH-D7200
# AH-D7200 --> Denon AH-D7200
# AH-D7200 --> Denon AH-D7200
# AH-D7200 --> Denon AH-D7200
# AH-D9200 --> Denon AH-D9200
# AH-D9200 --> Denon AH-D9200
# AH-D9200 --> Denon AH-D9200
# AH-D9200 --> Denon AH-D9200
# AH-D9200 --> Denon AH-D9200
# AH-D9200 --> Denon AH-D9200
# AirPods Max --> Apple AirPods Max
# AirPods Max --> Apple AirPods Max
# AirPods Max --> Apple AirPods Max
# AirPods Max --> Apple AirPods Max
# AirPods Max --> Apple AirPods Max
# AirPods Max --> Apple AirPods Max
# Sendy Audio Aiva --> Sendy Aiva
# Sendy Audio Aiva --> Sendy Aiva
# Sendy Audio Aiva --> Sendy Aiva
# Sendy Audio Aiva --> Sendy Aiva
# Sendy Audio Aiva --> Sendy Aiva
# Sendy Audio Aiva --> Sendy Aiva
# None --> Beyerdynamic Amiron Home S1
# None --> Beyerdynamic Amiron Home S1
# None --> Beyerdynamic Amiron Home S1
# None --> Beyerdynamic Amiron Home S1
# None --> Beyerdynamic Amiron Home S1
# None --> Beyerdynamic Amiron Home S1
# None --> Beyerdynamic Amiron Home S2
# None --> Beyerdynamic Amiron Home S2
# None --> Beyerdynamic Amiron Home S2
# None --> Beyerdynamic Amiron Home S2
# None --> Beyerdynamic Amiron Home S2
# None --> Beyerdynamic Amiron Home S2
# Amperior --> Sennheiser Amperior
# Amperior --> Sennheiser Amperior
# Amperior --> Sennheiser Amperior
# Amperior --> Sennheiser Amperior
# Amperior --> Sennheiser Amperior
# Amperior --> Sennheiser Amperior
# Hifiman Electronics Ananda --> Hifiman Ananda
# Hifiman Electronics Ananda --> Hifiman Ananda
# Hifiman Electronics Ananda --> Hifiman Ananda
# Hifiman Electronics Ananda --> Hifiman Ananda
# Hifiman Electronics Ananda --> Hifiman Ananda
# Hifiman Electronics Ananda --> Hifiman Ananda
# Aonic 50 --> Shure Aonic 50
# Aonic 50 --> Shure Aonic 50
# Aonic 50 --> Shure Aonic 50
# Aonic 50 --> Shure Aonic 50
# Aonic 50 --> Shure Aonic 50
# Aonic 50 --> Shure Aonic 50
# AR-H1 --> Acoustic Research AR-H1
# AR-H1 --> Acoustic Research AR-H1
# AR-H1 --> Acoustic Research AR-H1
# AR-H1 --> Acoustic Research AR-H1
# AR-H1 --> Acoustic Research AR-H1
# AR-H1 --> Acoustic Research AR-H1
# Hifiman Electronics Arya --> Hifiman Arya
# Hifiman Electronics Arya --> Hifiman Arya
# Hifiman Electronics Arya --> Hifiman Arya
# Hifiman Electronics Arya --> Hifiman Arya
# Hifiman Electronics Arya --> Hifiman Arya
# Hifiman Electronics Arya --> Hifiman Arya
# Arya Stealth --> Hifiman Arya Stealth
# Arya Stealth --> Hifiman Arya Stealth
# Arya Stealth --> Hifiman Arya Stealth
# Arya Stealth --> Hifiman Arya Stealth
# Arya Stealth --> Hifiman Arya Stealth
# Arya Stealth --> Hifiman Arya Stealth
# Atrium (BE2 perforated lambskin pads) --> ZMF Atrium (Perforated lambskin BE2 pads)
# Atrium (BE2 perforated lambskin pads) --> ZMF Atrium (Perforated lambskin BE2 pads)
# Atrium (BE2 perforated lambskin pads) --> ZMF Atrium (Perforated lambskin BE2 pads)
# Atrium (BE2 perforated lambskin pads) --> ZMF Atrium (Perforated lambskin BE2 pads)
# Atrium (BE2 perforated lambskin pads) --> ZMF Atrium (Perforated lambskin BE2 pads)
# Atrium (BE2 perforated lambskin pads) --> ZMF Atrium (Perforated lambskin BE2 pads)
# Atticus (Eikon suede) --> ZMF Atticus (Suede Eikon pads)
# Atticus (Eikon suede) --> ZMF Atticus (Suede Eikon pads)
# Atticus (Eikon suede) --> ZMF Atticus (Suede Eikon pads)
# Atticus (Eikon suede) --> ZMF Atticus (Suede Eikon pads)
# Atticus (Eikon suede) --> ZMF Atticus (Suede Eikon pads)
# Atticus (Eikon suede) --> ZMF Atticus (Suede Eikon pads)
# Aventho Wireless --> Beyerdynamic Aventho Wireless
# Aventho Wireless --> Beyerdynamic Aventho Wireless
# Aventho Wireless --> Beyerdynamic Aventho Wireless
# Aventho Wireless --> Beyerdynamic Aventho Wireless
# Aventho Wireless --> Beyerdynamic Aventho Wireless
# Aventho Wireless --> Beyerdynamic Aventho Wireless
# AWAS --> Audio Technica ATH-AWAS
# AWAS --> Audio Technica ATH-AWAS
# AWAS --> Audio Technica ATH-AWAS
# AWAS --> Audio Technica ATH-AWAS
# AWAS --> Audio Technica ATH-AWAS
# AWAS --> Audio Technica ATH-AWAS
# AWKT --> Audio Technica ATH-AWKT
# AWKT --> Audio Technica ATH-AWKT
# AWKT --> Audio Technica ATH-AWKT
# AWKT --> Audio Technica ATH-AWKT
# AWKT --> Audio Technica ATH-AWKT
# AWKT --> Audio Technica ATH-AWKT
# B60 --> BLON B60 S1
# B60 --> BLON B60 S1
# B60 --> BLON B60 S1
# B60 --> BLON B60 S1
# B60 --> BLON B60 S1
# B60 --> BLON B60 S1
# None --> BLON B60 S2
# None --> BLON B60 S2
# None --> BLON B60 S2
# None --> BLON B60 S2
# None --> BLON B60 S2
# None --> BLON B60 S2
# Barracuda X --> Razer Barracuda X
# Barracuda X --> Razer Barracuda X
# Barracuda X --> Razer Barracuda X
# Barracuda X --> Razer Barracuda X
# Barracuda X --> Razer Barracuda X
# Barracuda X --> Razer Barracuda X
# BeoPlay H7 --> B&O (Bang & Olufsen) BeoPlay H7
# BeoPlay H7 --> B&O (Bang & Olufsen) BeoPlay H7
# BeoPlay H7 --> B&O (Bang & Olufsen) BeoPlay H7
# BeoPlay H7 --> B&O (Bang & Olufsen) BeoPlay H7
# BeoPlay H7 --> B&O (Bang & Olufsen) BeoPlay H7
# BeoPlay H7 --> B&O (Bang & Olufsen) BeoPlay H7
# Blackshark V2 Pro --> Razer Blackshark V2 Pro
# Blackshark V2 Pro --> Razer Blackshark V2 Pro
# Blackshark V2 Pro --> Razer Blackshark V2 Pro
# Blackshark V2 Pro --> Razer Blackshark V2 Pro
# Blackshark V2 Pro --> Razer Blackshark V2 Pro
# Blackshark V2 Pro --> Razer Blackshark V2 Pro
# Blackshark V2 X --> Razer Blackshark V2 X
# Blackshark V2 X --> Razer Blackshark V2 X
# Blackshark V2 X --> Razer Blackshark V2 X
# Blackshark V2 X --> Razer Blackshark V2 X
# Blackshark V2 X --> Razer Blackshark V2 X
# Blackshark V2 X --> Razer Blackshark V2 X
# Borealis --> Aurorus Audio Borealis
# Borealis --> Aurorus Audio Borealis
# Borealis --> Aurorus Audio Borealis
# Borealis --> Aurorus Audio Borealis
# Borealis --> Aurorus Audio Borealis
# Borealis --> Aurorus Audio Borealis
# Cal1H --> Altiat Cal.1H
# Cal1H --> Altiat Cal.1H
# Cal1H --> Altiat Cal.1H
# Cal1H --> Altiat Cal.1H
# Cal1H --> Altiat Cal.1H
# Cal1H --> Altiat Cal.1H
# Campfire Cascade --> Campfire Audio Cascade
# Campfire Cascade --> Campfire Audio Cascade
# Campfire Cascade --> Campfire Audio Cascade
# Campfire Cascade --> Campfire Audio Cascade
# Campfire Cascade --> Campfire Audio Cascade
# Campfire Cascade --> Campfire Audio Cascade
# Celestee --> Focal Celestee
# Celestee --> Focal Celestee
# Celestee --> Focal Celestee
# Celestee --> Focal Celestee
# Celestee --> Focal Celestee
# Celestee --> Focal Celestee
# Clear (Mg pads) --> Focal Clear (Clear Mg pads)
# Clear (Mg pads) --> Focal Clear (Clear Mg pads)
# Clear (Mg pads) --> Focal Clear (Clear Mg pads)
# Clear (Mg pads) --> Focal Clear (Clear Mg pads)
# Clear (Mg pads) --> Focal Clear (Clear Mg pads)
# Clear (Mg pads) --> Focal Clear (Clear Mg pads)
# Focal Clear --> Focal Clear (Worn pads)
# Focal Clear --> Focal Clear (Worn pads)
# Focal Clear --> Focal Clear (Worn pads)
# Clear Mg --> Focal Clear Mg
# Clear Mg --> Focal Clear Mg
# Clear Mg --> Focal Clear Mg
# Clear Mg --> Focal Clear Mg
# Clear Mg --> Focal Clear Mg
# Clear Mg --> Focal Clear Mg
# Focal Clear --> Focal Clear (Worn pads)
# Focal Clear --> Focal Clear (Worn pads)
# Focal Clear --> Focal Clear (Worn pads)
# None --> Audeze CRBN S1
# None --> Audeze CRBN S1
# None --> Audeze CRBN S1
# None --> Audeze CRBN S1
# None --> Audeze CRBN S1
# None --> Audeze CRBN S1
# None --> Audeze CRBN S2
# None --> Audeze CRBN S2
# None --> Audeze CRBN S2
# None --> Audeze CRBN S2
# None --> Audeze CRBN S2
# None --> Audeze CRBN S2
# Crossfade 2 Wireless --> V-MODA Crossfade 2 Wireless
# Crossfade 2 Wireless --> V-MODA Crossfade 2 Wireless
# Crossfade 2 Wireless --> V-MODA Crossfade 2 Wireless
# Crossfade 2 Wireless --> V-MODA Crossfade 2 Wireless
# Crossfade 2 Wireless --> V-MODA Crossfade 2 Wireless
# Crossfade 2 Wireless --> V-MODA Crossfade 2 Wireless
# Crossfade LP2 --> V-MODA Crossfade LP2
# Crossfade LP2 --> V-MODA Crossfade LP2
# Crossfade LP2 --> V-MODA Crossfade LP2
# Crossfade LP2 --> V-MODA Crossfade LP2
# Crossfade LP2 --> V-MODA Crossfade LP2
# Crossfade LP2 --> V-MODA Crossfade LP2
# D8000 Pro --> Final Audio Design D8000 Pro
# D8000 Pro --> Final Audio Design D8000 Pro
# D8000 Pro --> Final Audio Design D8000 Pro
# D8000 Pro --> Final Audio Design D8000 Pro
# D8000 Pro --> Final Audio Design D8000 Pro
# D8000 Pro --> Final Audio Design D8000 Pro
# Deva (Passive) --> Hifiman Deva
# Deva (Passive) --> Hifiman Deva
# Deva (Passive) --> Hifiman Deva
# Deva (Passive) --> Hifiman Deva
# Deva (Passive) --> Hifiman Deva
# Deva (Passive) --> Hifiman Deva
# Deva Pro --> Hifiman Deva Pro
# Deva Pro --> Hifiman Deva Pro
# Deva Pro --> Hifiman Deva Pro
# Deva Pro --> Hifiman Deva Pro
# Deva Pro --> Hifiman Deva Pro
# Deva Pro --> Hifiman Deva Pro
# Diana Phi --> Abyss Diana Phi
# Diana Phi --> Abyss Diana Phi
# Diana Phi --> Abyss Diana Phi
# Diana Phi --> Abyss Diana Phi
# Diana Phi --> Abyss Diana Phi
# Diana Phi --> Abyss Diana Phi
# Diana V2 --> Abyss Diana V2
# Diana V2 --> Abyss Diana V2
# Diana V2 --> Abyss Diana V2
# Diana V2 --> Abyss Diana V2
# Diana V2 --> Abyss Diana V2
# Diana V2 --> Abyss Diana V2
# DT1350 --> Beyerdynamic DT1350
# DT1350 --> Beyerdynamic DT1350
# DT1350 --> Beyerdynamic DT1350
# DT1350 --> Beyerdynamic DT1350
# DT1350 --> Beyerdynamic DT1350
# DT1350 --> Beyerdynamic DT1350
# DT1770 Pro --> Beyerdynamic DT1770 Pro (Velour pads)
# DT1770 Pro --> Beyerdynamic DT1770 Pro (Velour pads)
# DT1770 Pro --> Beyerdynamic DT1770 Pro (Velour pads)
# DT1770 Pro --> Beyerdynamic DT1770 Pro (Velour pads)
# DT1770 Pro --> Beyerdynamic DT1770 Pro (Velour pads)
# DT1770 Pro --> Beyerdynamic DT1770 Pro (Velour pads)
# None --> Beyerdynamic DT1990 Pro S1 (Balanced pads)
# None --> Beyerdynamic DT1990 Pro S1 (Balanced pads)
# None --> Beyerdynamic DT1990 Pro S1 (Balanced pads)
# None --> Beyerdynamic DT1990 Pro S1 (Balanced pads)
# None --> Beyerdynamic DT1990 Pro S1 (Balanced pads)
# None --> Beyerdynamic DT1990 Pro S1 (Balanced pads)
# DT1990 Pro S2 (Analytical pads) (DIYAH filter) --> Beyerdynamic DT1990 Pro S2 (Analytical pads) (DIYAH filter)
# DT1990 Pro S2 (Analytical pads) (DIYAH filter) --> Beyerdynamic DT1990 Pro S2 (Analytical pads) (DIYAH filter)
# DT1990 Pro S2 (Analytical pads) (DIYAH filter) --> Beyerdynamic DT1990 Pro S2 (Analytical pads) (DIYAH filter)
# DT1990 Pro S2 (Analytical pads) (DIYAH filter) --> Beyerdynamic DT1990 Pro S2 (Analytical pads) (DIYAH filter)
# Elite (Alcantara pads) --> Meze Elite (Alcantara pads)
# Elite (Alcantara pads) --> Meze Elite (Alcantara pads)
# Elite (Alcantara pads) --> Meze Elite (Alcantara pads)
# Elite (Alcantara pads) --> Meze Elite (Alcantara pads)
# Elite (Alcantara pads) --> Meze Elite (Alcantara pads)
# Elite (Hybrid pads) --> Meze Elite (Hybrid pads)
# Elite (Hybrid pads) --> Meze Elite (Hybrid pads)
# Elite (Hybrid pads) --> Meze Elite (Hybrid pads)
# Elite (Hybrid pads) --> Meze Elite (Hybrid pads)
# Elite (Hybrid pads) --> Meze Elite (Hybrid pads)
# Elite (Hybrid pads) --> Meze Elite (Hybrid pads)
# Meze Empyrean --> Meze Empyrean S1
# Meze Empyrean --> Meze Empyrean S1
# Meze Empyrean --> Meze Empyrean S1
# Meze Empyrean --> Meze Empyrean S1
# Meze Empyrean --> Meze Empyrean S1
# Meze Empyrean --> Meze Empyrean S1
# None --> Meze Empyrean S2
# None --> Meze Empyrean S2
# None --> Meze Empyrean S2
# None --> Meze Empyrean S2
# None --> Meze Empyrean S2
# None --> Meze Empyrean S2
# ERA-1 --> Quad ERA-1
# ERA-1 --> Quad ERA-1
# ERA-1 --> Quad ERA-1
# ERA-1 --> Quad ERA-1
# ERA-1 --> Quad ERA-1
# ERA-1 --> Quad ERA-1
# Ergo 2 --> Precide ERGO 2
# Ergo 2 --> Precide ERGO 2
# Ergo 2 --> Precide ERGO 2
# Ergo 2 --> Precide ERGO 2
# Ergo 2 --> Precide ERGO 2
# Ergo 2 --> Precide ERGO 2
# ES-1a --> ES Lab ES-1a
# ES-1a --> ES Lab ES-1a
# ES-1a --> ES Lab ES-1a
# ES-1a --> ES Lab ES-1a
# ES-1a --> ES Lab ES-1a
# ES-1a --> ES Lab ES-1a
# ESP95X --> Koss ESP/95X
# ESP95X --> Koss ESP/95X
# ESP95X --> Koss ESP/95X
# ESP95X --> Koss ESP/95X
# ESP95X --> Koss ESP/95X
# ESP95X --> Koss ESP/95X
# Ether 2 --> DCA (Dan Clark Audio) Ether 2
# Ether 2 --> DCA (Dan Clark Audio) Ether 2
# Ether 2 --> DCA (Dan Clark Audio) Ether 2
# Ether 2 --> DCA (Dan Clark Audio) Ether 2
# Ether 2 --> DCA (Dan Clark Audio) Ether 2
# Ether 2 --> DCA (Dan Clark Audio) Ether 2
# Ether C Flow 1.1 --> DCA (Dan Clark Audio) Ether C Flow 1.1
# Ether C Flow 1.1 --> DCA (Dan Clark Audio) Ether C Flow 1.1
# Ether C Flow 1.1 --> DCA (Dan Clark Audio) Ether C Flow 1.1
# Ether C Flow 1.1 --> DCA (Dan Clark Audio) Ether C Flow 1.1
# Ether C Flow 1.1 --> DCA (Dan Clark Audio) Ether C Flow 1.1
# Ether C Flow 1.1 --> DCA (Dan Clark Audio) Ether C Flow 1.1
# Ether C --> MrSpeakers (Dan Clark Audio) Ether C
# Ether C --> MrSpeakers (Dan Clark Audio) Ether C
# Ether C --> MrSpeakers (Dan Clark Audio) Ether C
# Ether C --> MrSpeakers (Dan Clark Audio) Ether C
# Ether C --> MrSpeakers (Dan Clark Audio) Ether C
# Ether C --> MrSpeakers (Dan Clark Audio) Ether C
# Ether Flow 1.1 --> DCA (Dan Clark Audio) Ether Flow 1.1
# Ether Flow 1.1 --> DCA (Dan Clark Audio) Ether Flow 1.1
# Ether Flow 1.1 --> DCA (Dan Clark Audio) Ether Flow 1.1
# Ether Flow 1.1 --> DCA (Dan Clark Audio) Ether Flow 1.1
# Ether Flow 1.1 --> DCA (Dan Clark Audio) Ether Flow 1.1
# Ether Flow 1.1 --> DCA (Dan Clark Audio) Ether Flow 1.1
# EW9 --> Audio Technica ATH-EW9
# EW9 --> Audio Technica ATH-EW9
# EW9 --> Audio Technica ATH-EW9
# EW9 --> Audio Technica ATH-EW9
# EW9 --> Audio Technica ATH-EW9
# EW9 --> Audio Technica ATH-EW9
# FLY ANC --> Harman Kardon FLY ANC
# FLY ANC --> Harman Kardon FLY ANC
# FLY ANC --> Harman Kardon FLY ANC
# FLY ANC --> Harman Kardon FLY ANC
# FLY ANC --> Harman Kardon FLY ANC
# FLY ANC --> Harman Kardon FLY ANC
# G PRO X --> Logitech G PRO X
# G PRO X --> Logitech G PRO X
# G PRO X --> Logitech G PRO X
# G PRO X --> Logitech G PRO X
# G PRO X --> Logitech G PRO X
# G PRO X --> Logitech G PRO X
# G1 --> Audio Technica ATH-G1
# G1 --> Audio Technica ATH-G1
# G1 --> Audio Technica ATH-G1
# G1 --> Audio Technica ATH-G1
# G1 --> Audio Technica ATH-G1
# G1 --> Audio Technica ATH-G1
# G200 (Lambskin pads) --> HarmonicDyne G200 (Lambskin pads)
# G200 (Lambskin pads) --> HarmonicDyne G200 (Lambskin pads)
# G200 (Lambskin pads) --> HarmonicDyne G200 (Lambskin pads)
# G200 (Lambskin pads) --> HarmonicDyne G200 (Lambskin pads)
# G200 (Lambskin pads) --> HarmonicDyne G200 (Lambskin pads)
# G200 (Lambskin pads) --> HarmonicDyne G200 (Lambskin pads)
# G200 (Velour pads) --> HarmonicDyne G200 (Velour pads)
# G200 (Velour pads) --> HarmonicDyne G200 (Velour pads)
# G200 (Velour pads) --> HarmonicDyne G200 (Velour pads)
# G200 (Velour pads) --> HarmonicDyne G200 (Velour pads)
# G200 (Velour pads) --> HarmonicDyne G200 (Velour pads)
# G200 (Velour pads) --> HarmonicDyne G200 (Velour pads)
# G431 --> Logitech G431
# G431 --> Logitech G431
# G431 --> Logitech G431
# G431 --> Logitech G431
# G431 --> Logitech G431
# G431 --> Logitech G431
# G933s --> Logitech G933s
# G933s --> Logitech G933s
# G933s --> Logitech G933s
# G933s --> Logitech G933s
# G933s --> Logitech G933s
# G933s --> Logitech G933s
# GL2000 (double) (leather) --> Gold Planar GL2000 (double-sided) (Leather pads)
# GL2000 (double) (leather) --> Gold Planar GL2000 (double-sided) (Leather pads)
# GL2000 (double) (leather) --> Gold Planar GL2000 (double-sided) (Leather pads)
# GL2000 (double) (leather) --> Gold Planar GL2000 (double-sided) (Leather pads)
# GL2000 (double) (leather) --> Gold Planar GL2000 (double-sided) (Leather pads)
# GL2000 (double) (leather) --> Gold Planar GL2000 (double-sided) (Leather pads)
# GL2000 (double) (perf hybrid) --> Gold Planar GL2000 (double-sided) (Perforated hybrid pads)
# GL2000 (double) (perf hybrid) --> Gold Planar GL2000 (double-sided) (Perforated hybrid pads)
# GL2000 (double) (perf hybrid) --> Gold Planar GL2000 (double-sided) (Perforated hybrid pads)
# GL2000 (double) (perf hybrid) --> Gold Planar GL2000 (double-sided) (Perforated hybrid pads)
# GL2000 (double) (perf hybrid) --> Gold Planar GL2000 (double-sided) (Perforated hybrid pads)
# GL2000 (double) (perf hybrid) --> Gold Planar GL2000 (double-sided) (Perforated hybrid pads)
# GL2000 (leather) --> Gold Planar GL2000 (single-sided) (Leather pads)
# GL2000 (leather) --> Gold Planar GL2000 (single-sided) (Leather pads)
# GL2000 (leather) --> Gold Planar GL2000 (single-sided) (Leather pads)
# GL2000 (leather) --> Gold Planar GL2000 (single-sided) (Leather pads)
# GL2000 (leather) --> Gold Planar GL2000 (single-sided) (Leather pads)
# GL2000 (leather) --> Gold Planar GL2000 (single-sided) (Leather pads)
# GL2000 (perf hybrid) --> Gold Planar GL2000 (single-sided) (Perforated hybrid pads)
# GL2000 (perf hybrid) --> Gold Planar GL2000 (single-sided) (Perforated hybrid pads)
# GL2000 (perf hybrid) --> Gold Planar GL2000 (single-sided) (Perforated hybrid pads)
# GL2000 (perf hybrid) --> Gold Planar GL2000 (single-sided) (Perforated hybrid pads)
# GL2000 (perf hybrid) --> Gold Planar GL2000 (single-sided) (Perforated hybrid pads)
# GL2000 (perf hybrid) --> Gold Planar GL2000 (single-sided) (Perforated hybrid pads)
# GL850 --> Gold Planar GL850
# GL850 --> Gold Planar GL850
# GL850 --> Gold Planar GL850
# GL850 --> Gold Planar GL850
# GL850 --> Gold Planar GL850
# GL850 --> Gold Planar GL850
# GW100 --> Grado GW100
# GW100 --> Grado GW100
# GW100 --> Grado GW100
# GW100 --> Grado GW100
# GW100 --> Grado GW100
# GW100 --> Grado GW100
# GYFU --> Little Dot GYFU
# GYFU --> Little Dot GYFU
# GYFU --> Little Dot GYFU
# GYFU --> Little Dot GYFU
# GYFU --> Little Dot GYFU
# GYFU --> Little Dot GYFU
# H1 --> Tripowin H1
# H1 --> Tripowin H1
# H1 --> Tripowin H1
# H1 --> Tripowin H1
# H1 --> Tripowin H1
# H1 --> Tripowin H1
# HD25 Aluminium --> Sennheiser HD25 Aluminium
# HD25 Aluminium --> Sennheiser HD25 Aluminium
# HD25 Aluminium --> Sennheiser HD25 Aluminium
# HD25 Aluminium --> Sennheiser HD25 Aluminium
# HD25 Aluminium --> Sennheiser HD25 Aluminium
# HD25 Aluminium --> Sennheiser HD25 Aluminium
# HD25 Plus --> Sennheiser HD25 Plus
# HD25 Plus --> Sennheiser HD25 Plus
# HD25 Plus --> Sennheiser HD25 Plus
# Tea --> Mangird Tea
# Ten Five --> Fender Ten Five
# Ten Five --> Fender Ten Five
# Tenore --> Zero Audio Carbo Tenore ZH-DX200-CT
# Tenore --> Zero Audio Carbo Tenore ZH-DX200-CT
# Tequila 1 --> TFZ (The Fragrant Zither) Tequila 1
# Tequila 1 --> TFZ (The Fragrant Zither) Tequila 1
# Tequila --> Fearless Tequila
# Tequila --> Fearless Tequila
# Terminator --> Elysian Acoustic Labs Terminator
# Terminator --> Elysian Acoustic Labs Terminator
# None --> Elysian Acoustic Labs Terminator V2 S1
# None --> Elysian Acoustic Labs Terminator V2 S1
# None --> Elysian Acoustic Labs Terminator V2 S2
# None --> Elysian Acoustic Labs Terminator V2 S2
# Tevi --> Lypertek Tevi
# Tevi --> Lypertek Tevi
# TF10 --> Ultimate Ears Triple.Fi 10 (TF10)
# TF10 --> Ultimate Ears Triple.Fi 10 (TF10)
# None --> FitEar TG334 S1
# None --> FitEar TG334 S1
# None --> FitEar TG334 S2
# None --> FitEar TG334 S2
# None --> FitEar TG334 S3
# None --> FitEar TG334 S3
# Thirteen 6 --> Fender Thirteen 6
# Thirteen 6 --> Fender Thirteen 6
# Thummim --> MMR Thummim
# Thummim --> MMR Thummim
# Ti Galaxy --> TFZ (The Fragrant Zither) Ti Galaxy
# Ti Galaxy --> TFZ (The Fragrant Zither) Ti Galaxy
# Ti --> Periodic Audio Ti
# Ti --> Periodic Audio Ti
# Tiger qdc --> qdc Tiger
# Tiger qdc --> qdc Tiger
# Timeless --> 7Hz-Salnotes Timeless
# Timeless --> 7Hz-Salnotes Timeless
# Titan 1 --> DUNU Titan 1
# Titan 1 --> DUNU Titan 1
# Titan 3 --> DUNU Titan 3
# Titan 3 --> DUNU Titan 3
# None --> FitEar Titan S1
# None --> FitEar Titan S1
# Titan S RM --> DUNU Titan S
# Titan S RM --> DUNU Titan S
# None --> FitEar Titan S2
# None --> FitEar Titan S2
# TM2 --> Fostex TM2
# TM2 --> Fostex TM2
# Tone Free --> LG Tone Free
# Tone Free --> LG Tone Free
# Topaz Filterless --> Yinyoo Topaz (filterless)
# Topaz Filterless --> Yinyoo Topaz (filterless)
# TP10 --> Tripowin TP10
# TP10 --> Tripowin TP10
# Track Air Plus --> Libratone Track Air Plus
# Track Air Plus --> Libratone Track Air Plus
# Traillii --> Oriolus Traillii
# Traillii --> Oriolus Traillii
# Treble --> HYLA TE-5T
# Treble --> HYLA TE-5T
# TRI i3 --> KBEar TRI I3
# TRI i3 --> KBEar TRI I3
# Trident Aya --> Aya Trident
# Trident Aya --> Aya Trident
# Trinity Brass --> Jomo Audio Trinity Brass
# Trinity Brass --> Jomo Audio Trinity Brass
# Trinity --> Jomo Audio Trinity
# Trinity --> Jomo Audio Trinity
# None --> 64 Audio tia Trio S1
# None --> 64 Audio tia Trio S1
# None --> 64 Audio tia Trio S2
# None --> 64 Audio tia Trio S2
# Triple Driver --> 1MORE Triple Driver
# Triple Driver --> 1MORE Triple Driver
# Triple --> Eartech Triple
# Triple --> Eartech Triple
# Triton S2 --> Symphonium Audio Triton
# Triton S2 --> Symphonium Audio Triton
# TrueConnect --> RHA TrueConnect
# TrueConnect --> RHA TrueConnect
# Truth --> Dita Truth
# Truth --> Dita Truth
# TSH-HR1000K --> fineEars TSH-HR1000K
# TSH-HR1000K --> fineEars TSH-HR1000K
# TSMR-3 Pro 000 --> Tansio Mirai (TSMR) TSMR-3 Pro (000 setting)
# TSMR-3 Pro 000 --> Tansio Mirai (TSMR) TSMR-3 Pro (000 setting)
# TSMR-3 Pro 003 --> Tansio Mirai (TSMR) TSMR-3 Pro (003 setting)
# TSMR-3 Pro 003 --> Tansio Mirai (TSMR) TSMR-3 Pro (003 setting)
# TSMR-3 Pro 020 --> Tansio Mirai (TSMR) TSMR-3 Pro (020 setting)
# TSMR-3 Pro 020 --> Tansio Mirai (TSMR) TSMR-3 Pro (020 setting)
# TSMR-3 Pro 023 --> Tansio Mirai (TSMR) TSMR-3 Pro (023 setting)
# TSMR-3 Pro 023 --> Tansio Mirai (TSMR) TSMR-3 Pro (023 setting)
# TSMR-3 Pro 100 --> Tansio Mirai (TSMR) TSMR-3 Pro (100 setting)
# TSMR-3 Pro 100 --> Tansio Mirai (TSMR) TSMR-3 Pro (100 setting)
# TSMR-3 Pro 103 --> Tansio Mirai (TSMR) TSMR-3 Pro (103 setting)
# TSMR-3 Pro 103 --> Tansio Mirai (TSMR) TSMR-3 Pro (103 setting)
# TSMR-3 Pro 120 --> Tansio Mirai (TSMR) TSMR-3 Pro (120 setting)
# TSMR-3 Pro 120 --> Tansio Mirai (TSMR) TSMR-3 Pro (120 setting)
# TSMR-3 Pro 123 --> Tansio Mirai (TSMR) TSMR-3 Pro (123 setting)
# TSMR-3 Pro 123 --> Tansio Mirai (TSMR) TSMR-3 Pro (123 setting)
# TSMR-5 003 --> Tansio Mirai (TSMR) TSMR-5 (003 setting)
# TSMR-5 003 --> Tansio Mirai (TSMR) TSMR-5 (003 setting)
# TSMR-5 020 --> Tansio Mirai (TSMR) TSMR-5 (020 setting)
# TSMR-5 020 --> Tansio Mirai (TSMR) TSMR-5 (020 setting)
# TSMR-5 100 --> Tansio Mirai (TSMR) TSMR-5 (100 setting)
# TSMR-5 100 --> Tansio Mirai (TSMR) TSMR-5 (100 setting)
# TSMR-5 123 --> Tansio Mirai (TSMR) TSMR-5 (123 setting)
# TSMR-5 123 --> Tansio Mirai (TSMR) TSMR-5 (123 setting)
# Tsuru --> Fatfreq Tsuru
# Tsuru --> Fatfreq Tsuru
# TT --> HUM TT
# TT --> HUM TT
# Tumuri --> Satolex Tumuri DH303-A1
# Tumuri --> Satolex Tumuri DH303-A1
# Tux 5 --> Noble Audio Tux 5
# Tux 5 --> Noble Audio Tux 5
# Twilight Softears --> Softears Twilight
# Twilight Softears --> Softears Twilight
# Twins Bass --> Aroma Audio Twins (Bass on)
# Twins Bass --> Aroma Audio Twins (Bass on)
# Twins Treble --> Aroma Audio Twins (Treble on)
# Twins Treble --> Aroma Audio Twins (Treble on)
# TWS1 Grell --> Grell Audio TWS/1
# TWS1 Grell --> Grell Audio TWS/1
# TWS1 --> Edifier TWS1
# TWS1 --> Edifier TWS1
# TWS2000 S2 --> Tin HiFi TWS2000
# TWS2000 S2 --> Tin HiFi TWS2000
# TWS5 --> Edifier TWS5
# TWS5 --> Edifier TWS5
# TWS6 --> Edifier TWS6
# TWS6 --> Edifier TWS6
# TWS600 --> Hifiman TWS600
# TWS600 --> Hifiman TWS600
# Type 711 --> Madoo Type 711
# Type 711 --> Madoo Type 711
# Tzar 350 --> Heir Audio Tzar 350
# Tzar 350 --> Heir Audio Tzar 350
# None --> 64 Audio U12t S1
# None --> 64 Audio U12t S1
# None --> 64 Audio U12t S3
# None --> 64 Audio U12t S3
# None --> 64 Audio U18Tzar S1
# None --> 64 Audio U18Tzar S1
# None --> 64 Audio U18Tzar S2
# None --> 64 Audio U18Tzar S2
# U2 --> Stealthsonics U2
# U2 --> Stealthsonics U2
# U4 --> Stealthsonics U4
# U4 --> Stealthsonics U4
# U9 JDM --> Stealthsonics U9 JDM
# U9 JDM --> Stealthsonics U9 JDM
# U9 --> Stealthsonics U9
# U9 --> Stealthsonics U9
# UCD-2 --> Unknown Customs UCD-2
# UCD-2 --> Unknown Customs UCD-2
# UCD-3 --> Unknown Customs UCD-3
# UCD-3 --> Unknown Customs UCD-3
# UE11 --> Ultimate Ears UE11
# UE11 --> Ultimate Ears UE11
# None --> Ultimate Ears UE18+ (3rd Gen)
# None --> Ultimate Ears UE18+ (3rd Gen)
# None --> Ultimate Ears UE18+ (2nd Gen) S1
# None --> Ultimate Ears UE18+ (2nd Gen) S1
# None --> Ultimate Ears UE18+ (2nd Gen) S2
# None --> Ultimate Ears UE18+ (2nd Gen) S2
# UE4 Pro --> Ultimate Ears UE4 Pro
# UE4 Pro --> Ultimate Ears UE4 Pro
# UE5 --> Ultimate Ears UE5
# UE5 --> Ultimate Ears UE5
# UE6 --> Ultimate Ears UE6
# UE6 --> Ultimate Ears UE6
# UE7 --> Ultimate Ears UE7
# UE7 --> Ultimate Ears UE7
# UE900S --> Ultimate Ears UE900S
# UE900S --> Ultimate Ears UE900S
# UERM --> Ultimate Ears Reference Monitor (UERM) (Custom)
# UERM --> Ultimate Ears Reference Monitor (UERM) (Custom)
# UERR --> Ultimate Ears Reference Remastered (UERR)
# UERR --> Ultimate Ears Reference Remastered (UERR)
# UM Pro 10 --> Westone UM Pro 10
# UM Pro 10 --> Westone UM Pro 10
# UM Pro 20 --> Westone UM Pro 20
# UM Pro 20 --> Westone UM Pro 20
# UM Pro 30 --> Westone UM Pro 30
# UM Pro 30 --> Westone UM Pro 30
# UM Pro 50 --> Westone UM Pro 50
# Uranus --> qdc Uranus
# Uranus --> qdc Uranus
# V14 00 --> ThieAudio Voyager 14 (V14) (00 setting)
# V14 00 --> ThieAudio Voyager 14 (V14) (00 setting)
# V14 02 --> ThieAudio Voyager 14 (V14) (02 setting)
# V14 02 --> ThieAudio Voyager 14 (V14) (02 setting)
# V14 10 --> ThieAudio Voyager 14 (V14) (10 setting)
# VE7 --> Vision Ears VE7
# VE7 --> Vision Ears VE7
# VE8 C --> Vision Ears VE8 (custom) S1
# VE8 C --> Vision Ears VE8 (custom) S1
# VE8 C S2 --> Vision Ears VE8 (custom) S2
# VE8 C S2 --> Vision Ears VE8 (custom) S2
# VE8 --> Vision Ears VE8 (universal)
# VE8 --> Vision Ears VE8 (universal)
# Vega 2020 --> Campfire Audio Vega (2020)
# Vega 2020 --> Campfire Audio Vega (2020)
# None --> Campfire Audio Vega (Pre-2020) S1
# None --> Campfire Audio Vega (Pre-2020) S1
# None --> Campfire Audio Vega (Pre-2020) S2
# None --> Campfire Audio Vega (Pre-2020) S2
# Velvet Standard --> Earsonics Velvet (Standard mode)
# Velvet Standard --> Earsonics Velvet (Standard mode)
# Velvet Tight --> Earsonics Velvet (Tight mode)
# Velvet Warm --> Earsonics Velvet (Warm mode)
# Verb --> LH Labs Verb
# Verb --> LH Labs Verb
# Versa --> Alclair Versa
# Versa --> Alclair Versa
# Vesper --> QoA (Queen of Audio) Vesper S1
# Vesper --> QoA (Queen of Audio) Vesper S1
# Vesper S2 --> QoA (Queen of Audio) Vesper S2
# Vesper S2 --> QoA (Queen of Audio) Vesper S2
# VG4 000 --> BGVP VG4 (000 setting)
# VG4 000 --> BGVP VG4 (000 setting)
# VG4 003 --> BGVP VG4 (003 setting)
# VG4 003 --> BGVP VG4 (003 setting)
# VG4 020 --> BGVP VG4 (020 setting)
# VG4 020 --> BGVP VG4 (020 setting)
# VG4 100 --> BGVP VG4 (100 setting)
# VG4 100 --> BGVP VG4 (100 setting)
# Viento Bass --> Hidition Viento-Reference (universal) B
# Viento Bass Mids --> Hidition Viento-Reference (universal) D
# Viento Bass Mids --> Hidition Viento-Reference (universal) D
# Viento Bass --> Hidition Viento-Reference (universal) B
# Viento --> Hidition Viento-Reference (universal) A
# Viento Mids --> Hidition Viento-Reference (universal) C
# Viento Mids --> Hidition Viento-Reference (universal) C
# Viento --> Hidition Viento-Reference (universal) A
# Viento-A C --> Hidition Viento-A (Custom)
# Viento-A C --> Hidition Viento-A (Custom)
# Viento-B C --> Hidition Viento-B (Custom)
# Viento-B C --> Hidition Viento-B (Custom)
# Viento-D C --> Hidition Viento-D (Custom)
# Viento-D C --> Hidition Viento-D (Custom)
# Violet --> Hidition Violet
# Violet --> Hidition Violet
# Vista --> Jaybirds Vista
# Vista --> Jaybirds Vista
# None --> QKZ VK4 (Pre-revision) S1
# None --> QKZ VK4 (Pre-revision) S1
# None --> QKZ VK4 (Revised) S1
# None --> QKZ VK4 (Revised) S1
# None --> QKZ VK4 (Revised) S2
# None --> QKZ VK4 (Revised) S2
# None --> QKZ VK4 (Pre-revision) S2
# None --> QKZ VK4 (Pre-revision) S2
# Volans --> Astrotec Volans
# Volans --> Astrotec Volans
# VR1 --> Simphonio VR1
# VR1 --> Simphonio VR1
# VSD1S --> VSonic VSD1S
# VSD1S --> VSonic VSD1S
# VSD2S --> VSonic VSD2S
# VSD2S --> VSonic VSD2S
# VSD3S --> VSonic VSD3S
# VSD3S --> VSonic VSD3S
# Vulkan --> DUNU Vulkan
# Vulkan --> DUNU Vulkan
# VxV --> FiR VxV
# VxV --> FiR VxV
# W10 --> Westone W10
# W10 --> Westone W10
# W20 --> Westone W20
# W20 --> Westone W20
# W30 --> Westone W30
# W30 --> Westone W30
# W40 --> Westone W40
# W40 --> Westone W40
# W50 --> Westone W50
# W50 --> Westone W50
# W500 --> AAW (Advanced AcousticWerkes) W500
# W500 --> AAW (Advanced AcousticWerkes) W500
# W60 --> Westone W60
# W60 --> Westone W60
# W80 --> Westone W80
# W80 --> Westone W80
# W900 --> AAW (Advanced AcousticWerkes) W900
# W900 --> AAW (Advanced AcousticWerkes) W900
# Waltz --> Hidition Waltz
# Waltz --> Hidition Waltz
# WF-1000XM3 --> Sony WF-1000XM3 (ANC off)
# WF-1000XM3 NC --> Sony WF-1000XM3 (ANC on)
# WF-1000XM3 NC --> Sony WF-1000XM3 (ANC on)
# WF-1000XM3 --> Sony WF-1000XM3 (ANC off)
# WF-1000XM4 Bass Boost --> Sony WF-1000XM4 (Bass Boost preset)
# WF-1000XM4 Bass Boost --> Sony WF-1000XM4 (Bass Boost preset)
# WF-1000XM4 Bright --> Sony WF-1000XM4 (Bright preset)
# WF-1000XM4 Bright --> Sony WF-1000XM4 (Bright preset)
# WF-1000XM4 Excited --> Sony WF-1000XM4 (Excited preset)
# WF-1000XM4 Excited --> Sony WF-1000XM4 (Excited preset)
# WF-1000XM4 --> Sony WF-1000XM4
# WF-1000XM4 Mellow --> Sony WF-1000XM4 (Mellow preset)
# WF-1000XM4 Mellow --> Sony WF-1000XM4 (Mellow preset)
# WF-1000XM4 --> Sony WF-1000XM4
# WF-1000XM4 Relaxed --> Sony WF-1000XM4 (Relaxed preset)
# WF-1000XM4 Relaxed --> Sony WF-1000XM4 (Relaxed preset)
# WF-1000XM4 Speech --> Sony WF-1000XM4 (Speech preset)
# WF-1000XM4 Speech --> Sony WF-1000XM4 (Speech preset)
# WF-1000XM4 Treble Boost --> Sony WF-1000XM4 (Treble Boost preset)
# WF-1000XM4 Treble Boost --> Sony WF-1000XM4 (Treble Boost preset)
# WF-1000XM4 Vocal --> Sony WF-1000XM4 (Vocal preset)
# WF-1000XM4 Vocal --> Sony WF-1000XM4 (Vocal preset)
# WF-SP800N --> Sony WF-SP800N
# WF-SP800N --> Sony WF-SP800N
# WF-XB700 --> Sony WF-XB700
# WF-XB700 --> Sony WF-XB700
# WH3 --> HiBy WH3
# WH3 --> HiBy WH3
# Witch Girl Pro --> Aroma Audio Witch Girl Pro
# Witch Girl Pro --> Aroma Audio Witch Girl Pro
# Witch Girl S --> Aroma Audio Witch Girl S
# Witch Girl S --> Aroma Audio Witch Girl S
# Witch Girl W12 --> Aroma Audio Witch Girl W12
# Witch Girl W12 --> Aroma Audio Witch Girl W12
# XBA-40 --> Sony XBA-40
# XBA-40 --> Sony XBA-40
# None --> Sony XBA-A3 S1
# XBA-A3 Mod --> Sony XBA-A3 Modded
# XBA-A3 Mod --> Sony XBA-A3 Modded
# None --> Sony XBA-A3 S1
# None --> Sony XBA-A3 S2
# None --> Sony XBA-A3 S2
# XBA-H3 --> Sony XBA-H3
# XBA-H3 --> Sony XBA-H3
# XBA300 --> Sony XBA-300
# XBA300 --> Sony XBA-300
# Xelento --> Beyerdynamic Xelento
# Xelento --> Beyerdynamic Xelento
# Xenon-6 C --> FiR Xenon 6 (Custom)
# Xenon-6 C --> FiR Xenon 6 (Custom)
# Xenon-6 --> FiR Xenon 6 (Universal)
# Xenon-6 --> FiR Xenon 6 (Universal)
# Yao --> Aroma Audio Yao
# Yao --> Aroma Audio Yao
# YB04 --> Cayin YB04
# YB04 --> Cayin YB04
# Yume --> See Audio Yume S1
# Yume --> See Audio Yume S1
# Z1R Filterless --> Sony IER-Z1R S1 (Filterless)
# Z1R Filterless --> Sony IER-Z1R S1 (Filterless)
# None --> Sony IER-Z1R S1
# None --> Sony IER-Z1R S1
# None --> Sony IER-Z1R S2
# None --> Sony IER-Z1R S2
# None --> Sony IER-Z1R S3
# None --> Sony IER-Z1R S3
# None --> Sony IER-Z1R S4
# None --> Sony IER-Z1R S4
# None --> Sony IER-Z1R S5
# None --> Sony IER-Z1R S5
# None --> Sony IER-Z1R S6
# None --> Sony IER-Z1R S6
# None --> Sony IER-Z1R S7
# None --> Sony IER-Z1R S7
# Z5 --> Sony XBA-Z5
# Z5 --> Sony XBA-Z5
# ZAS --> KZ (Knowledge Zenith) ZAS
# ZAS --> KZ (Knowledge Zenith) ZAS
# None --> DUNU Zen Pro S2
# None --> DUNU Zen Pro S2
# Zenith Black --> IMR Zenith (Black nozzle)
# Zenith Black --> IMR Zenith (Black nozzle)
# Zenith Blue --> IMR Zenith (Blue nozzle)
# Zenith Blue --> IMR Zenith (Blue nozzle)
# Zenith Gold --> IMR Zenith (Gold nozzle)
# Zenith Gold --> IMR Zenith (Gold nozzle)
# Zenith Orange --> IMR Zenith (Orange nozzle)
# Zenith Orange --> IMR Zenith (Orange nozzle)
# Zenith Pink --> IMR Zenith (Pink nozzle)
# Zenith Pink --> IMR Zenith (Pink nozzle)
# Zero --> BGVP Zero
# Zero --> BGVP Zero
# None --> 7Hz-Salnotes Zero S1
# None --> 7Hz-Salnotes Zero S1
# None --> 7Hz-Salnotes Zero S2
# None --> 7Hz-Salnotes Zero S2
# None --> 7Hz-Salnotes Zero S3
# None --> 7Hz-Salnotes Zero S3
# Zero Tanch --> Tanchjim Zero
# Zero Tanch --> Tanchjim Zero
# None --> Truthear Zero S10
# None --> Truthear Zero S10
# None --> Truthear Zero S2
# None --> Truthear Zero S2
# None --> Truthear Zero S3
# None --> Truthear Zero S3
# None --> Truthear Zero S4
# None --> Truthear Zero S4
# None --> Truthear Zero S5
# None --> Truthear Zero S5
# None --> Truthear Zero S6
# None --> Truthear Zero S6
# None --> Truthear Zero S7
# None --> Truthear Zero S7
# None --> Truthear Zero S8
# None --> Truthear Zero S8
# None --> Truthear Zero S9
# None --> Truthear Zero S9
# None --> Truthear Zero:RED S1 (Bass+)
# None --> Truthear Zero:RED S1 (Bass+)
# None --> Truthear Zero:RED S1
# None --> Truthear Zero:RED S1
# None --> Truthear Zero:RED S10 (Bass+)
# None --> Truthear Zero:RED S10 (Bass+)
# None --> Truthear Zero:RED S10
# None --> Truthear Zero:RED S10
# None --> Truthear Zero:RED S2 (Bass+)
# None --> Truthear Zero:RED S2 (Bass+)
# None --> Truthear Zero:RED S2
# None --> Truthear Zero:RED S2
# None --> Truthear Zero:RED S3 (Bass+)
# None --> Truthear Zero:RED S3 (Bass+)
# None --> Truthear Zero:RED S3
# None --> Truthear Zero:RED S3
# None --> Truthear Zero:RED S4 (Bass+)
# None --> Truthear Zero:RED S4 (Bass+)
# None --> Truthear Zero:RED S4
# None --> Truthear Zero:RED S4
# None --> Truthear Zero:RED S5 (Bass+)
# None --> Truthear Zero:RED S5 (Bass+)
# None --> Truthear Zero:RED S5
# None --> Truthear Zero:RED S5
# None --> Truthear Zero:RED S6 (Bass+)
# None --> Truthear Zero:RED S6 (Bass+)
# None --> Truthear Zero:RED S6
# None --> Truthear Zero:RED S6
# None --> Truthear Zero:RED S7 (Bass+)
# None --> Truthear Zero:RED S7 (Bass+)
# None --> Truthear Zero:RED S7
# None --> Truthear Zero:RED S7
# None --> Truthear Zero:RED S8 (Bass+)
# None --> Truthear Zero:RED S8 (Bass+)
# None --> Truthear Zero:RED S8
# None --> Truthear Zero:RED S8
# None --> Truthear Zero:RED S9 (Bass+)
# None --> Truthear Zero:RED S9 (Bass+)
# None --> Truthear Zero:RED S9
# None --> Truthear Zero:RED S9
# None --> KZ (Knowledge Zenith) ZS3 S1
# None --> KZ (Knowledge Zenith) ZS3 S1
# None --> KZ (Knowledge Zenith) ZS3 S2
# None --> KZ (Knowledge Zenith) ZS3 S2
# None --> KZ (Knowledge Zenith) ZS5v1 S1
# None --> KZ (Knowledge Zenith) ZS5v1 S1
# None --> KZ (Knowledge Zenith) ZS5v1 S2
# None --> KZ (Knowledge Zenith) ZSX S1
# None --> KZ (Knowledge Zenith) ZSX S1
# None --> KZ (Knowledge Zenith) ZSX S2
# None --> KZ (Knowledge Zenith) ZSX S2

# %%
print(crawler.crawl_index.find_one(url='file://measurements/crinacle/raw_data/IEC60318-4 IEM Measurements (TSV txt)/1Custom Dual L.txt'))
# Out:
# "file://measurements/crinacle/raw_data/IEC60318-4 IEM Measurements (TSV txt)/1Custom Dual L.txt"	"1Custom Dual"	"1Custom SA02"	"in-ear"	"711"

# %%
print(crawler.name_index.find_one(url='file://measurements/crinacle/raw_data/IEC60318-4 IEM Measurements (TSV txt)/1Custom Dual L.txt'))
# Out:
# "file://measurements/crinacle/raw_data/IEC60318-4 IEM Measurements (TSV txt)/1Custom Dual L.txt"	"1Custom Dual"	"1Custom SA02"	"in-ear"	"711"
