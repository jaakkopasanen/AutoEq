# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import sys
from pathlib import Path
ROOT_PATH = Path().absolute().parent
if str(ROOT_PATH) not in sys.path:
    sys.path.insert(1, str(ROOT_PATH))
import matplotlib.pyplot as plt
from frequency_response import FrequencyResponse
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fr = FrequencyResponse.read_from_csv(ROOT_PATH.joinpath('results', 'oratory1990', 'harman_over-ear_2018', 'Audeze LCD-4', 'Audeze LCD-4.csv'))

# %%
fr.plot_graph()
plt.show()

# %%
fir = fr.minimum_phase_impulse_response(f_res=2)

# %%
plt.plot(20*np.log10(np.abs(fir)))
plt.show()

# %%
np.sum(np.abs(fir))
# Out:
# 1.8275043644088678

# %%
fir_norm = fir / np.sum(np.abs(fir))

# %%
plt.plot(20*np.log10(np.abs(fir_norm)))
plt.show()

# %%
print(np.max(np.abs(fir)), np.max(np.abs(fir_norm)))
# Out:
# 0.3852276372822296 0.21079437334577142

# %%
conv = np.convolve(fir, np.ones(fir.size * 3))
plt.plot(conv)
plt.show()

# %%
np.max(np.abs(conv))
# Out:
# 0.7027049677261858
