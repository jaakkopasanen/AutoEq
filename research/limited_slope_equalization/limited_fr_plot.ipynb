# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pathlib import Path
ROOT_PATH = Path().resolve().parent.parent
DIR_PATH = Path().resolve()
if str(ROOT_PATH) not in sys.path:
    sys.path.insert(1, str(ROOT_PATH))

# %%
import numpy as np
import matplotlib.pyplot as plt
from frequency_response_limited import FrequencyResponseLimited

# %%
fr = FrequencyResponseLimited.read_from_csv(ROOT_PATH.joinpath('measurements/oratory1990/data/onear/Beyerdynamic T1 2nd Generation/Beyerdynamic T1 2nd Generation.csv'))
target = FrequencyResponseLimited.read_from_csv(ROOT_PATH.joinpath('compensation/harman_over-ear_2018.csv'))
fr.process(compensation=target, bass_boost_gain=0.0, bass_boost_fc=105, bass_boost_q=0.7, equalize=True)
fig, ax = fr.plot_graph(show=False)
fig.set_size_inches(20, 12)
plt.show()
